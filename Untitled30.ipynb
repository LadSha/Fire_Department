# %%
import pandas as pd
file="/Users/ladanshamaei/Desktop/ladan/CS/Data Incubator/TDI2/Incidents_Responded_to_by_Fire_Companies.csv"
df=pd.read_csv(file, low_memory=False)
df.head()
# Out:
#    IM_INCIDENT_KEY FIRE_BOX  \
# 0         55672688     2147
# 1         55672692     0818
# 2         55672693     9656
# 3         55672695     7412
# 4         55672697     4019
#
#                                   INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 0                  300 - Rescue, EMS incident, other  01/01/2013 12:00:20 AM
# 1  735A - Unwarranted alarm/defective condition o...  01/01/2013 12:00:37 AM
# 2                  300 - Rescue, EMS incident, other  01/01/2013 12:01:17 AM
# 3                412 - Gas leak (natural gas or LPG)  01/01/2013 12:02:32 AM
# 4  735A - Unwarranted alarm/defective condition o...  01/01/2013 12:01:49 AM
#
#         ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 0  01/01/2013 12:14:23 AM            1.0      01/01/2013 12:20:06 AM
# 1  01/01/2013 12:09:03 AM            3.0      01/01/2013 12:30:06 AM
# 2  01/01/2013 12:04:55 AM            1.0      01/01/2013 12:15:18 AM
# ...

# %%
a=len(df.groupby(['INCIDENT_TYPE_DESC']).groups["111 - Building fire"])

# %%
b=len(df.groupby(['INCIDENT_TYPE_DESC']).groups["651 - Smoke scare, odor of smoke"])

# %%
round(a/b,10)
# Out:
# 0.0878904676

# %%
b1=len(df[((df["INCIDENT_TYPE_DESC"]=='710 - Malicious, mischievous false call, other') &(df["BOROUGH_DESC"]=="1 - Manhattan"))])

# %%
a1=len(df[((df["INCIDENT_TYPE_DESC"]=='710 - Malicious, mischievous false call, other') &(df["BOROUGH_DESC"]=="3 - Staten Island"))])

# %%
round(a1/b1,10)
# Out:
# 0.3278922345

# %%
b1
# Out:
# 25240

# %%
a1
# Out:
# 8276

# %%
x=df[(df['INCIDENT_TYPE_DESC']=="111 - Building fire")]
x
# Out:
#          IM_INCIDENT_KEY FIRE_BOX   INCIDENT_TYPE_DESC  \
# 90              55672965     2595  111 - Building fire
# 198             55673299     2591  111 - Building fire
# 439             55673870     1601  111 - Building fire
# 491             55674012     7973  111 - Building fire
# 568             55674170     1726  111 - Building fire
# 615             55674270     0336  111 - Building fire
# 749             55674538     0912  111 - Building fire
# 947             55674934     1839  111 - Building fire
# 1040            55675138     0966  111 - Building fire
# 1049            55675164     7343  111 - Building fire
# 1056            55675190     1069  111 - Building fire
# 1280            55675781     5034  111 - Building fire
# 1454            55676269     1621  111 - Building fire
# 1484            55676348     1074  111 - Building fire
# 1543            55676486     4402  111 - Building fire
# 1607            55676639     2124  111 - Building fire
# ...

# %%
z=pd.to_datetime(x['ARRIVAL_DATE_TIME'])-pd.to_datetime(x['INCIDENT_DATE_TIME'])
# Out:
# count                     13069
# mean     0 days 00:03:35.508225
# std      0 days 00:01:28.955645
# min           -1 days +23:54:55
# 25%             0 days 00:02:51
# 50%             0 days 00:03:27
# 75%             0 days 00:04:09
# max             0 days 01:28:59
# dtype: object

# %%
z.quantile(0.75)
# Out:
# Timedelta('0 days 00:04:09')

# %%
df['ARRIVAL_DATE_TIME']=pd.to_datetime(df['ARRIVAL_DATE_TIME'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/src/datetime.pxd in datetime._string_to_dts()
#
# ValueError: Error parsing datetime string "01/02/2014 01:28:42 PM" at position 2
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-6d1ddf9c3b29> in <module>()
# ----> 1 df['ARRIVAL_DATE_TIME']=pd.to_datetime(df['ARRIVAL_DATE_TIME'])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin)
#     371     elif isinstance(arg, ABCSeries):
#     372         from pandas import Series
# --> 373         values = _convert_listlike(arg._values, True, format)
# ...

# %%
df.groupby('INCIDENT_TYPE_DESC' is '113 - Cooking fire, confined to container'

# %%
x1=df[(df['INCIDENT_TYPE_DESC']=="113 - Cooking fire, confined to container")]

# %%
x1['ARRIVAL_DATE_TIME']=pd.to_datetime(x1['ARRIVAL_DATE_TIME'])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
file1="/Users/ladanshamaei/Desktop/ladan/CS/Data Incubator/TDI2/2010+Census+Population+By+Zipcode+(ZCTA).csv"
zcode=pd.read_csv(file1, low_memory=False)
zcode=zcode.rename(columns={"Zip Code ZCTA":"ZIP_CODE"})
zcode.ZIP_CODE=zcode.ZIP_CODE.astype(str)
a1=pd.merge(x,zcode)
b1=a1.groupby(['ZIP_CODE','2010 Census Population']).agg({'INCIDENT_DATE_TIME':"count"}).reset_index()
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(b1['2010 Census Population'],b1['INCIDENT_DATE_TIME'])
r_value**2
#num_fire=a1.groupby(['ZIP_CODE'])[['INCIDENT_DATE_TIME']].count()
#df2=pd.DataFrame(num_fire)
#df2=df2.rename(columns={'INCIDENT_DATE_TIME':"NUM-INCIDENTS"})
# Out:
# 0.5973393948657465

# %%
df_CO=df.dropna(subset=['CO_DETECTOR_PRESENT_DESC'])
bins=[20,30,40,50,60,70]
df0=pd.cut(df_CO.TOTAL_INCIDENT_DURATION,bins,retbins=True,include_lowest=True)

# %%
df20_30_Total=df_CO[(df_CO['TOTAL_INCIDENT_DURATION']>=20)&(df_CO['TOTAL_INCIDENT_DURATION']<=30)]
k1=df20_30_Total.groupby(['CO_DETECTOR_PRESENT_DESC'])['INCIDENT_DATE_TIME'].count().reset_index()
k1[k1.CO_DETECTOR_PRESENT_DESC=='No'].INCIDENT_DATE_TIME/k1[k1.CO_DETECTOR_PRESENT_DESC=='Yes'].INCIDENT_DATE_TIME
def ratio(bin):
    df=df_CO[(df_CO['TOTAL_INCIDENT_DURATION']>=bin)&(df_CO['TOTAL_INCIDENT_DURATION']<=(bin+10))]
    k1=df.groupby(['CO_DETECTOR_PRESENT_DESC'])['INCIDENT_DATE_TIME'].count().reset_index()
    return(k1[k1.CO_DETECTOR_PRESENT_DESC=='No'].INCIDENT_DATE_TIME/k1[k1.CO_DETECTOR_PRESENT_DESC=='Yes'].INCIDENT_DATE_TIME)
ratio(50)
# Out:
# 0   NaN
# 1   NaN
# Name: INCIDENT_DATE_TIME, dtype: float64

# %%
bin=20
for i in range (0,5):
    def ratio(bin):
    df=df_CO[(df_CO['TOTAL_INCIDENT_DURATION']>=bin)&(df_CO['TOTAL_INCIDENT_DURATION']<=(bin+10))]
    k1=df.groupby(['CO_DETECTOR_PRESENT_DESC'])['INCIDENT_DATE_TIME'].count().reset_index()
    return(k1[k1.CO_DETECTOR_PRESENT_DESC=='No'].INCIDENT_DATE_TIME/k1[k1.CO_DETECTOR_PRESENT_DESC=='Yes'].INCIDENT_DATE_TIME)
ratio(50)

# %%
bin=60
df=df_CO[(df_CO['TOTAL_INCIDENT_DURATION']>=bin)&(df_CO['TOTAL_INCIDENT_DURATION']<=(bin+10))]
k1=df.groupby(['CO_DETECTOR_PRESENT_DESC'])['INCIDENT_DATE_TIME'].count().reset_index()
(k1[k1.CO_DETECTOR_PRESENT_DESC=='No'].INCIDENT_DATE_TIME/k1[k1.CO_DETECTOR_PRESENT_DESC=='Yes'].INCIDENT_DATE_TIME)
# Out:
# 0   NaN
# 1   NaN
# Name: INCIDENT_DATE_TIME, dtype: float64

# %%
k1
# Out:
#   CO_DETECTOR_PRESENT_DESC  INCIDENT_DATE_TIME
# 0                       No                   3
# 1                      Yes                  14

# %%
df20_30_Total=df_CO[(df_CO['TOTAL_INCIDENT_DURATION']>=20)&(df_CO['TOTAL_INCIDENT_DURATION']<=30)]
#df20_30_NO=df20_30_Total[df20_30_Total['CO_DETECTOR_PRESENT_DESC']=='No']
#df20_30_NO=df20_30_Total[df20_30_Total['CO_DETECTOR_PRESENT_DESC']=='No'].count()
#df20_30_YES=df20_30_Total[df20_30_Total['CO_DETECTOR_PRESENT_DESC']=='Yes'].count()
k1=df20_30_Total.groupby(['CO_DETECTOR_PRESENT_DESC'])['INCIDENT_DATE_TIME'].count().reset_index()
k1[k1.CO_DETECTOR_PRESENT_DESC=='No'].INCIDENT_DATE_TIME/k1[k1.CO_DETECTOR_PRESENT_DESC=='Yes'].INCIDENT_DATE_TIME
df30_40_Total=df_CO[(df_CO['TOTAL_INCIDENT_DURATION']>=30)&(df_CO['TOTAL_INCIDENT_DURATION']<=40)]
k2=df30_40_Total.groupby(['CO_DETECTOR_PRESENT_DESC'])['INCIDENT_DATE_TIME'].count().reset_index()
k2[k2.CO_DETECTOR_PRESENT_DESC=='No'].INCIDENT_DATE_TIME/k2[k2.CO_DETECTOR_PRESENT_DESC=='Yes'].INCIDENT_DATE_TIME
#def ratio(df10,bin):
    #d=df10[(df10['TOTAL_INCIDENT_DURATION']>=bin)&(df_CO['TOTAL_INCIDENT_DURATION']<=(bin+10))]
    #k1=d.groupby(['CO_DETECTOR_PRESENT_DESC'])['INCIDENT_DATE_TIME'].count().reset_index()
   # return((k1['INCIDENT_DATE_TIME'][k1.CO_DETECTOR_PRESENT_DESC=='No'])/(k1['INCIDENT_DATE_TIME'][k1.CO_DETECTOR_PRESENT_DESC=='Yes'])
#bin = 20
#kk=pd.DataFrame(columns=list('AB'))
for i in range (0,5):
   # rat=ratio(df_CO,bin)
   # kk0=pd.DataFrame([[bin+5,rat]],columns=list('AB'))
    #kk=kk.append(kk0)
    bin=bin+10

# %%
k1
# Out:
#   CO_DETECTOR_PRESENT_DESC  INCIDENT_DATE_TIME
# 0                      Yes                   5

# %%
def ratio(df10,bin):
    d=df10[(df10['TOTAL_INCIDENT_DURATION']>=bin)&(df_CO['TOTAL_INCIDENT_DURATION']<=(bin+10))]
    k1=d.groupby(['CO_DETECTOR_PRESENT_DESC'])['INCIDENT_DATE_TIME'].count().reset_index()
    return((k1[k1.CO_DETECTOR_PRESENT_DESC=='No'].INCIDENT_DATE_TIME/k1[k1.CO_DETECTOR_PRESENT_DESC=='Yes'].INCIDENT_DATE_TIME)
# Out:
#   File "<ipython-input-385-9ff20e78c615>", line 4
#     return((k1[k1.CO_DETECTOR_PRESENT_DESC=='No'].INCIDENT_DATE_TIME/k1[k1.CO_DETECTOR_PRESENT_DESC=='Yes'].INCIDENT_DATE_TIME)
#                                                                                                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
#x.loc[x['A'] == 2, 'B'].values[0]
k1.loc[k1['CO_DETECTOR_PRESENT_DESC']=='Yes','INCIDENT_DATE_TIME']
#k1['INCIDENT_DATE_TIME'][k1.CO_DETECTOR_PRESENT_DESC=='No']/k1['INCIDENT_DATE_TIME'][k1.CO_DETECTOR_PRESENT_DESC=='Yes']
# Out:
# 0    5
# Name: INCIDENT_DATE_TIME, dtype: int64

# %%
df30_40_Total=df_CO[(df_CO['TOTAL_INCIDENT_DURATION']>=30)&(df_CO['TOTAL_INCIDENT_DURATION']<=40)]
k2=df30_40_Total.groupby(['CO_DETECTOR_PRESENT_DESC'])['INCIDENT_DATE_TIME'].count().reset_index()
k2[k2.CO_DETECTOR_PRESENT_DESC=='No'].INCIDENT_DATE_TIME/k2[k2.CO_DETECTOR_PRESENT_DESC=='Yes'].INCIDENT_DATE_TIME
# Out:
# 0   NaN
# 1   NaN
# Name: INCIDENT_DATE_TIME, dtype: float64

# %%
df30_40_Total
k2=df30_40_Total.groupby(['CO_DETECTOR_PRESENT_DESC'])['INCIDENT_DATE_TIME'].count().reset_index()
k2.dtypes
# Out:
# CO_DETECTOR_PRESENT_DESC    object
# INCIDENT_DATE_TIME           int64
# dtype: object

# %%
k2['INCIDENT_DATE_TIME'][k2.CO_DETECTOR_PRESENT_DESC=='No']
# Out:
# 0    4
# Name: INCIDENT_DATE_TIME, dtype: int64

# %%
df20_30_NO.head()
# Out:
# Empty DataFrame
# Columns: [IM_INCIDENT_KEY, FIRE_BOX, INCIDENT_TYPE_DESC, INCIDENT_DATE_TIME, ARRIVAL_DATE_TIME, UNITS_ONSCENE, LAST_UNIT_CLEARED_DATE_TIME, HIGHEST_LEVEL_DESC, TOTAL_INCIDENT_DURATION, ACTION_TAKEN1_DESC, ACTION_TAKEN2_DESC, ACTION_TAKEN3_DESC, PROPERTY_USE_DESC, STREET_HIGHWAY, ZIP_CODE, BOROUGH_DESC, FLOOR, CO_DETECTOR_PRESENT_DESC, FIRE_ORIGIN_BELOW_GRADE_FLAG, STORY_FIRE_ORIGIN_COUNT, FIRE_SPREAD_DESC, DETECTOR_PRESENCE_DESC, AES_PRESENCE_DESC, STANDPIPE_SYS_PRESENT_FLAG]
# Index: []
#
# [0 rows x 24 columns]

# %%
k2
# Out:
#   CO_DETECTOR_PRESENT_DESC  INCIDENT_DATE_TIME
# 0                       No                   4
# 1                      Yes                   9

# %%
df_CO['TOTAL_INCIDENT_DURATION'].describe()
# Out:
# count     29675.000000
# mean       1663.493345
# std        6209.661616
# min           0.000000
# 25%         864.000000
# 50%        1163.000000
# 75%        1679.000000
# max      765985.000000
# Name: TOTAL_INCIDENT_DURATION, dtype: float64

# %%
df_CO.head()
# Out:
#      IM_INCIDENT_KEY FIRE_BOX  \
# 28          55672777     2332
# 153         55673169     0097
# 194         55673290     0105
# 249         55673419     3184
# 449         55673903     3318
#
#                                    INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 28   746 - Carbon monoxide detector activation, no CO  01/01/2013 12:20:13 AM
# 153   736 - CO detector activation due to malfunction  01/01/2013 01:47:48 AM
# 194                  400 - Hazardous condition, other  01/01/2013 02:21:49 AM
# 249                    424 - Carbon monoxide incident  01/01/2013 03:03:40 AM
# 449                    424 - Carbon monoxide incident  01/01/2013 06:38:05 AM
#
#           ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 28   01/01/2013 12:25:39 AM            2.0      01/01/2013 12:41:53 AM
# 153  01/01/2013 01:52:39 AM            2.0      01/01/2013 01:54:26 AM
# 194  01/01/2013 02:30:05 AM            2.0      01/01/2013 02:47:36 AM
# ...

# %%
kkk = pd.DataFrame( columns=list('AB'))

# %%
z00=pd.DataFrame([[1,2]],columns=list('AB'))
kkk.append(z00)
# Out:
#    A  B
# 0  1  2
